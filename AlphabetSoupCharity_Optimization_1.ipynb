# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns= ['EIN', 'NAME', 'ORGANIZATION', 'SPECIAL_CONSIDERATIONS'], inplace=True)

application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  STATUS  \
# 0              T10       Independent          C1000    ProductDev       1
# 1               T3       Independent          C2000  Preservation       1
# 2               T5  CompanySponsored          C3000    ProductDev       1
# 3               T3  CompanySponsored          C2000  Preservation       1
# 4               T3       Independent          C1000     Heathcare       1
#
#       INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0              0     5000              1
# 1         1-9999   108590              1
# 2              0     5000              0
# 3    10000-24999     6692              1
# 4  100000-499999   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
val_counts1 = application_df['APPLICATION_TYPE'].value_counts()
val_counts1
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = val_counts1[val_counts1 < 1000].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
val_counts2 = application_df['CLASSIFICATION'].value_counts()
val_counts2[val_counts2 > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = val_counts2[val_counts2 < 2000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       1
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  AFFILIATION_CompanySponsored  \
# 0                    0                    0                             0
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns='IS_SUCCESSFUL').values
y = application_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=100, activation='tanh', input_dim=32))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=40, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               3300
#
#  dense_1 (Dense)             (None, 40)                4040
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# ...
# Total params: 8181 (31.96 KB)
# Trainable params: 8181 (31.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5789 - accuracy: 0.7170
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5699 - accuracy: 0.7234
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5683 - accuracy: 0.7241
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5676 - accuracy: 0.7248
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5668 - accuracy: 0.7250
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5663 - accuracy: 0.7241
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5656 - accuracy: 0.7257
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5658 - accuracy: 0.7247
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5650 - accuracy: 0.7247
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5795 - accuracy: 0.7266 - 466ms/epoch - 2ms/step
# Loss: 0.5795384049415588, Accuracy: 0.7266472578048706

# %%
# This optimization trial did not result in better accuracy. The changes made from the original include:
# Dropping 2 additional columns (Organization and Special Considerations).
# The binning for application type was changed to < 1000 and classification was changed to < 2000.
# The first layer was changed to 'tahn' and a third 'relu' layer was added.
# The change in columns made it necessary to change the input to 32.
# The units for the input layers were changed to 100, 80, and 20, respectively.
